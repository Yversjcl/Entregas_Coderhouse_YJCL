# %% [markdown]
# <a href="https://colab.research.google.com/github/Yversjcl/Desaf-o_1_Datasets_Potenciales/blob/main/Datasets_Caruzo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # *Primer Desafío*: Elección de datasets potenciales (Unidad V)

# %% [markdown]
# # ***Dataset 1***
# Sector Objetivo: Telecomunicaciones
#
# Fuente de datos: Construcción Propia (KPI´S Operacionales canal IVR de atención de clientes)

# %% [markdown]
# ***Objetivo General:*** Establecer parametros que permitan proyectar el comportamiento de indicadores operacionales del canal de atencion de clientes IVR.

# %%
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
df1= pd.read_csv('/content/drive/MyDrive/Dataset_1_IVR_KPIS_2022.csv', sep=';')
# Out:
# /usr/local/lib/python3.8/dist-packages/IPython/core/interactiveshell.py:3326: DtypeWarning: Columns (8,12) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
df1
# Out:
#         PERIODO       Fecha   MERCADO     IVR IVR_ATENCION  ORIGEN  \
# 0        202209   9/12/2022  POSTPAGO  103_CC
# 1        202209   9/12/2022  POSTPAGO  103_CC
# 2        202209   9/12/2022  POSTPAGO  103_CC
# 3        202212  12/23/2022  POSTPAGO  103_SS       IVR_SS  600103
# 4        202209   9/16/2022  POSTPAGO  103_CC       IVR_CC  600103
# ...         ...         ...       ...     ...          ...     ...
# 637184   202210   10/1/2022  POSTPAGO  103_CC       IVR_CC  IVR_CC
# 637185   202210  10/29/2022  POSTPAGO  103_CC       IVR_CC  IVR_CC
# 637186   202211  11/29/2022  POSTPAGO  103_CC       IVR_CC  IVR_CC
# 637187   202211   11/2/2022  POSTPAGO  103_CC       IVR_CC  IVR_CC
# 637188   202210   10/1/2022  POSTPAGO  103_CC       IVR_CC  IVR_CC
#
#                     PERFILADO                           ULTIMA_MARCA  \
# 0              S2S_MOVIL_PLUS  TRANSF_COG_CL_TRANSFER_CONV_S2S_MOVIL
# 1                              TRANSF_COG_CL_TRANSFER_CONV_S2S_HOGAR
# ...

# %% [markdown]
# **Contexto Analítico**
#
# Este conjunto de datos contiene reporte de clientes que interactuaron a través del canal IVR de una reconocida empresa de telecomunicaciones, durante el último cuatrimestre del 2022, principalmente clasificados por Indicador operacional registrado.
#
# El objetivo de contar con este dataset, es poder desarrollar un estudio que permita proyectar el desempeño de estos indicadores por mercado, a saber, Postpago. Prepago y Hogar durante el 2023, esto último permite planificar la orientación de los recursos dirigidos al diseño de autoatenciones y la planificación del Q de ejecutivos y sus skills para brindar una atención más eficiente.

# %% [markdown]
# # *Dataset 2*: Mejores peliculas de acuerdo a clasificacion técnica Rotten Tomatoes

# %% [markdown]
# ### Sector Objetivo: Cinematográfico

# %% [markdown]
# *Fuente de datos*: https://www.kaggle.com/datasets/thedevastator/rotten-tomatoes-top-movies-ratings-and-technical

# %% [markdown]
# ***Objetivo General***: Explorar el comportamiento de la critica, los aspectos técnicos y las recaudaciones cinematográficas durante los ultimos  Años

# %%
df2= pd.read_csv('/content/drive/MyDrive/Dataset_2_rotten_tomatoes_top_movies.csv')

# %%
df2
# Out:
#       Unnamed: 0                              title  year  \
# 0              0                      Black Panther  2018
# 1              1                  Avengers: Endgame  2019
# 2              2     Mission: Impossible -- Fallout  2018
# 3              3                 Mad Max: Fury Road  2015
# 4              4  Spider-Man: Into the Spider-Verse  2018
# ...          ...                                ...   ...
# 1605        1605                             Priest  2011
# 1606        1606                     September Dawn  2006
# 1607        1607                   American Outlaws  2001
# 1608        1608                          Jonah Hex  2010
# 1609        1609                      Texas Rangers  2001
#
#                                                synopsis  critic_score  \
# 0     After the death of his father, T'Challa return...            96
# 1     Adrift in space with no food or water, Tony St...            94
# ...

# %% [markdown]
# **Contexto Analítico**
#
# Este dataset se incorpora para aplicar una estadistica descriptiva de las principales variables asociadas a la critica cinematografica, clasificar las de mayor Box y las de mejor valoración.

# %% [markdown]
# # ***Dataset 3***
# Sector Objetivo: Telecomunicaciones
#
# Fuente de datos: Construcción Propia (Literales de encuestas postatención a clientes de los canales WSP Y RRSS )

# %% [markdown]
# ***Objetivo general***: Construir un estudio de **análisis de sentimiento** a clientes encuestados post atención de ejecutivos, en los canales WSP y RRSS, para descubrir el sentimiento general de los clientes, sobre las atenciones y los canales y fortalecer los aspectos que resulten generar sentiminetos negativos y neutros en cada journey, Atención y centro de atención

# %%
df3=pd.read_csv('/content/drive/MyDrive/Dataset_3_WSP_RRSS_Sentiment.csv', sep= ';')

# %%
df3
# Out:
#        Fecha encuesta Hora encuesta   Fecha atencion Hora atencion  \
# 0     02-03-2022 0:00   0,420497685  01-03-2022 0:00   0,773831019
# 1     02-03-2022 0:00   0,452731481  01-03-2022 0:00   0,520925926
# 2     02-03-2022 0:00   0,419421296  01-03-2022 0:00    0,81431713
# 3     02-03-2022 0:00   0,465972222  01-03-2022 0:00   0,743009259
# 4     02-03-2022 0:00     0,4534375  01-03-2022 0:00   0,372384259
# ...               ...           ...              ...           ...
# 2066  01-04-2022 0:00    0,56306713  31-03-2022 0:00   0,890243056
# 2067  01-04-2022 0:00   0,565648148  31-03-2022 0:00   0,584166667
# 2068  01-04-2022 0:00   0,567048611  31-03-2022 0:00   0,447152778
# 2069  01-04-2022 0:00   0,590694444  31-03-2022 0:00   0,814571759
# 2070  01-04-2022 0:00   0,589826389  31-03-2022 0:00   0,638391204
#
#                                                 Literal  Global  \
# 0     No se me dio una solución concreta en primer l...       1
# ...

# %% [markdown]
# ***Contexto Analítico***
#
# Este data set está compuesto por clientes que fueron atendidos a través de canales como WSP o RRSS y que pasaron a una atención con ejecutivos a través de mensajería, el objetivo es analizar el sentimientom de estos clientes sobre sus atenciones, centros, motivos y ejecutivos, para esllo es fundamenta la variable "Literal" que es el texto transcrito del motivo de la evaluación que realizó el cliente.
